# %%
file = open("LambdaTimerData2.txt", "r")

transcript = file.read()

# %%
lines = transcript.splitlines()

# %%
for i in range(1, len(lines), 2):
    print(lines[i])
# Out:
# 3000  1291.5893333333333
# 5000  709.9426
# 7000  555.1298571428572
# 9000  541.0417777777777
# 11000  564.3640909090909
# 13000  460.4736923076923
# 15000  397.2252
# 17000  455.3876470588235
# 19000  470.4382631578947
# 21000  613.7924761904762
# 23000  589.5936956521739
# 25000  485.68552
# 27000  519.3424074074074
# 29000  478.75006896551724
# 31000  485.71551612903227
# 33000  510.1445151515152
# 35000  496.14897142857143
# 37000  502.76262162162163
# 39000  532.0832051282051
#
# 3000  395.66866666666664
# 5000  414.6696
# 7000  687.7037142857143
# 9000  813.4593333333333
# 11000  1257.7624545454546
# 13000  1050.9401538461539
# 15000  1147.1365333333333
# 17000  1030.9754705882353
# 19000  1105.2407368421052
# 21000  1304.1099523809523
# 23000  1388.998956521739
# 25000  1453.79096
# 27000  1188.7477407407407
# 29000  1178.3893448275862
# 31000  1625.1415483870967
# 33000  1225.4348181818182
# 35000  1320.1811142857143
# 37000  1331.496135135135
# 39000  1442.484205128205
#
# ...
